# %% [markdown]
# <a href="https://colab.research.google.com/github/milekm01/python12/blob/main/MiPrimerPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tipos de datos:
# int = Numeros Enteros
# str = Cadena de texto
# float = Flotante decimal
# booleano = true or false

# %%
nombre = input ("¿Cual es tu nombre")
edad = int(input("¿Cual es tu edad"))
print(f"Hola {nombre} tienes {edad} años")
# Out:
# ¿Cual es tu nombre Milena
# ¿Cual es tu edad 22
# Hola  Milena tienes 22 años

# %%
#Definimos una variable
def saludar(nombre):
 print(f"Hola{nombre} bienvenid@ al taller de python")
saludar (nombre)
# Out:
# Hola Milena bienvenid@ al taller de python

# %%
def mayor_de_edad(edad):
  if edad >= 18:
    print ("Eres mayor de edad")
  elif edad <= 11:
    print ("Eres un niño pequeño")
  else:
    print("Eres mayor de edad")
mayor_de_edad(edad)
# Out:
# Eres mayor de edad
